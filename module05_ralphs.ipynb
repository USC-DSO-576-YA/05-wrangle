# %% [markdown]
# # Module 5 Homework
#
# ## Clean the Ralphs sales data
#
# Prepare a reusable sales table from the Ralphs grocery csv. The goal is to
# extract useful information from messy text, choose appropriate data types, and
# check that your cleaning rules preserve the meaning of the source data.
#
# Work individually in one Jupyter notebook named `module05_ralphs.ipynb`. Use
# short code cells, with a brief explanation before each cleaning step. This
# assignment does not require charts, a dashboard, or phrase mining.
#
# **Submission:** Upload `module05_ralphs.ipynb` to the Module 5 homework
# assignment on Gradescope. Follow the posted course calendar for the deadline.

# %% [markdown]
# ### How to use this starter
#
# Save this notebook as **`module05_ralphs.ipynb`** in the top-level **`05-wrangle`**
# folder, beside `data/`. Open it in VS Code or Jupyter and select your course
# Python environment. Work through the sections in order. You can begin in class
# and continue in the same notebook afterward.
#
# - Read each Markdown instruction, then write your code in the cell below it.
# - Edit the Markdown response spaces to explain your approach and observations.
# - Add extra cells when useful. Keep code cells short and retain the instructions.
# - Only the loading cell is completed. Empty cells do not perform any cleaning;
#   running this starter unchanged does **not** complete the homework.
# - When finished, restart the kernel, run all cells, and save with outputs visible.
#   Upload this one notebook to the Module 5 homework assignment on Gradescope.

# %% [markdown]
# ## Data and setup
#
# The data is in your [YA Module 5 repository](https://github.com/USC-DSO-576-YA/05-wrangle),
# at `data/11-ralphs_sales.csv.gz`. Save your notebook in the top-level
# `05-wrangle` folder, beside the `data` folder, so the relative path below works.
# This starter loads the source as strings so you can inspect the original text:

# %%
import pandas as pd

raw = pd.read_csv("data/11-ralphs_sales.csv.gz", dtype="string")

# %% [markdown]
# ## Using Codex
#
# You may use Codex for hints, explanations, and feedback on code you have tried.
# Do not ask it to complete the notebook, write a finished cleaning function for
# you. Before asking for help, write what you expected it to do. If you cannot
# get started, first describe the intended transformation in plain language.
# Ask about one step at a time.
#
# For example: “Here is my attempt and the output I expected. Give me one hint
# about why it does not work.”

# %% [markdown]
# ## 1 Inspect before changing anything
#
# Display the first few rows, the column names, the number of rows, and the
# number of distinct non-missing values in each column. Inspect the distinct
# values in `Geography` and several examples from `Time` and `Product`.
#
# Before using Codex, write brief answers to these questions:
#
# - What does one row represent? Use the geography, reporting period, and product
#   information in your answer.
# - Which fields contain numbers stored as text? Which number-looking field is
#   actually an identifier?
# - Show one raw description and explain which pieces you expect to extract.

# %% [markdown]
# ### Inspect the original export
#
# Display the requested rows, columns, row count, distinct-value counts, and source examples. Do not change `raw`.
#
# **My approach or prediction:**
#
# *Replace this sentence with your own explanation before writing the code.*

# %%
# Your code here

# %% [markdown]
# ### Explain and check
#
# Before using Codex, answer all three questions above: what one row represents, which fields are measurements versus identifiers, and what you expect to extract from one raw description.
#
# **My response:**
#
# *Write your response here.*

# %% [markdown]
# ## 2 Clean dates and sales amounts
#
# Create these columns in `sales`:
#
# | Column | Required meaning and representation |
# | --- | --- |
# | `Week Ending` | Date following “Ending” in `Time`, converted to a pandas datetime value. |
# | `Description` | A lowercase version of the raw `Product` description. |
# | `Dollar Sales` | Numeric sales revenue, with currency formatting removed. |
# | `Unit Sales` | Numeric number of packages sold. |
#
# Inspect the actual formatting before choosing a cleaning rule. After converting
# each numeric or date column, count missing results and inspect any raw values
# that could not be converted. Report zero if there are no failures. Do not
# replace an unsuccessful conversion with zero.

# %% [markdown]
# ### Create your working table
#
# Create a separate DataFrame named `sales` while leaving `raw` unchanged and preserving every source row.
#
# **My approach or prediction:**
#
# *Replace this sentence with your own explanation before writing the code.*

# %%
# Your code here

# %% [markdown]
# ### Clean the description
#
# Create `Description` as specified above. Show a few source descriptions beside their cleaned versions.
#
# **My approach or prediction:**
#
# *Replace this sentence with your own explanation before writing the code.*

# %%
# Your code here

# %% [markdown]
# ### Extract the reporting date
#
# Create `Week Ending`. Count missing results and inspect the original `Time` values for any conversion failures.
#
# **My approach or prediction:**
#
# *Replace this sentence with your own explanation before writing the code.*

# %%
# Your code here

# %% [markdown]
# ### Convert dollar sales
#
# Make `Dollar Sales` numeric. Count missing results and inspect the raw values for any conversion failures. Do not turn failed conversions into zero.
#
# **My approach or prediction:**
#
# *Replace this sentence with your own explanation before writing the code.*

# %%
# Your code here

# %% [markdown]
# ### Convert unit sales
#
# Make `Unit Sales` numeric. Count missing results and inspect the raw values for any conversion failures. Do not turn failed conversions into zero.
#
# **My approach or prediction:**
#
# *Replace this sentence with your own explanation before writing the code.*

# %%
# Your code here

# %% [markdown]
# ### Explain and check
#
# Explain the formatting your rules handled and what you found when checking missing or unsuccessful conversions. Report zero when there are no failures.
#
# **My response:**
#
# *Write your response here.*

# %% [markdown]
# ## 3 Separate packaging from the product description
#
# Create `Packaging` from the description. The original exercise uses `bag`,
# `canister`, and `assorted`; inspect how those words appear in this file before
# writing your rule. Keep unmatched or ambiguous cases missing and report them.
#
# Create a Series named `prefix` containing the description before the packaging
# information. Remove packaging modifiers such as `plastic` and `resealable`
# from that boundary, without deleting meaningful words elsewhere in a product
# description. Remove leftover surrounding whitespace.
#
# Display five distinct examples with their `Description`, `Packaging`, and
# `prefix`. Include an example with a packaging modifier if one is present.

# %% [markdown]
# ### Identify packaging
#
# Create `Packaging`. Report unmatched or ambiguous cases and leave them missing.
#
# **My approach or prediction:**
#
# *Replace this sentence with your own explanation before writing the code.*

# %%
# Your code here

# %% [markdown]
# ### Extract the prefix
#
# Create the Series `prefix`, handling packaging modifiers at the boundary and removing surrounding whitespace.
#
# **My approach or prediction:**
#
# *Replace this sentence with your own explanation before writing the code.*

# %%
# Your code here

# %% [markdown]
# ### Check packaging and prefix
#
# Display five distinct examples with `Description`, `Packaging`, and `prefix`, including a packaging modifier if one is present.
#
# **My approach or prediction:**
#
# *Replace this sentence with your own explanation before writing the code.*

# %%
# Your code here

# %% [markdown]
# ### Explain and check
#
# Explain how you treated modifiers without deleting meaningful words elsewhere. Describe any unmatched or ambiguous cases.
#
# **My response:**
#
# *Write your response here.*

# %% [markdown]
# ## 4 Separate product family and flavor
#
# Use `prefix` to create `Product` and `Flavor`. Here, `Product` means the brand
# and product family together, not just the brand. For example:
#
# | Prefix | Product | Flavor |
# | --- | --- | --- |
# | `doritos tortilla chip nacho cheese` | `doritos tortilla chip` | `nacho cheese` |
# | `lays potato chip classic` | `lays potato chip` | `classic` |
# | `cheetos cheese snack flamin hot` | `cheetos cheese snack` | `flamin hot` |
#
# Inspect the distinct prefixes and write down the product-family boundaries
# your code recognizes. Apply the same rules to every row, rather than manually
# editing individual records. Do not assume the first word is always the full
# product family or that the last word is always the full flavor.
#
# Display five distinct results. Report how many rows your rules could not
# confidently separate, and show up to three examples. Keep those uncertain
# fields missing; do not invent a product or flavor to make the table complete.
# A documented limitation is preferable to a confident but incorrect split.

# %% [markdown]
# ### Inspect product-family boundaries
#
# Inspect the distinct prefixes before choosing reusable rules.
#
# **My approach or prediction:**
#
# *Replace this sentence with your own explanation before writing the code.*

# %%
# Your code here

# %% [markdown]
# ### My product-family rules
#
# *Write the boundaries your rules will recognize and how you will handle uncertain cases. Do not assume a one-word product family or flavor.*

# %% [markdown]
# ### Separate product and flavor
#
# Create `Product` and `Flavor` using the same rules across rows. Keep uncertain fields missing.
#
# **My approach or prediction:**
#
# *Replace this sentence with your own explanation before writing the code.*

# %%
# Your code here

# %% [markdown]
# ### Check your coverage
#
# Display five distinct results. Count rows that could not be confidently separated and show up to three examples.
#
# **My approach or prediction:**
#
# *Replace this sentence with your own explanation before writing the code.*

# %%
# Your code here

# %% [markdown]
# ### Explain and check
#
# Explain any uncertainty or limitation in your rules. Do not invent values to make the table complete.
#
# **My response:**
#
# *Write your response here.*

# %% [markdown]
# ## 5 Extract identifiers and package sizes
#
# Create these additional columns:
#
# - `Product Code`: the identifier after the final hyphen in `Description`.
#   Keep it as a string, including leading zeros. It is not a measurement.
# - `Oz`: the numeric package size explicitly expressed in ounces in the
#   description. Your rule must handle integers, decimals such as `9.75`, and
#   decimals written without a leading zero, such as `.75`.
# - `Price Per Oz`: average dollars paid per ounce sold for that record.
#
# Use this definition for the last column:
#
# ```text
# Price Per Oz = Dollar Sales / (Unit Sales * Oz)
# ```
#
# Only calculate it when revenue is present and both unit sales and package
# size are present and greater than zero. Otherwise leave the result missing.
# Do not fill unknown package sizes with zero or a typical size. If a description
# does not support one unambiguous package weight, flag it for review and explain
# why you did not infer a value.
#
# Report how many rows have missing `Oz` and how many have missing `Price Per Oz`.
# Inspect examples rather than assuming that every missing result is a mistake.

# %% [markdown]
# ### Extract the product code
#
# Create `Product Code` as a string and check that leading zeros are preserved.
#
# **My approach or prediction:**
#
# *Replace this sentence with your own explanation before writing the code.*

# %%
# Your code here

# %% [markdown]
# ### Extract the package weight
#
# Create numeric `Oz`, following the size and ambiguity requirements above. Count missing weights and inspect examples.
#
# **My approach or prediction:**
#
# *Replace this sentence with your own explanation before writing the code.*

# %%
# Your code here

# %% [markdown]
# ### Calculate price per ounce
#
# Create `Price Per Oz` using the stated definition and validity conditions. Count missing results and inspect examples.
#
# **My approach or prediction:**
#
# *Replace this sentence with your own explanation before writing the code.*

# %%
# Your code here

# %% [markdown]
# ### Explain and check
#
# Explain your treatment of missing or ambiguous weights and invalid denominators. Include the requested missing-value counts in your outputs.
#
# **My response:**
#
# *Write your response here.*

# %% [markdown]
# ## 6 Show that the cleaning worked
#
# Include the following evidence in your notebook:
#
# 1. **Preserved records:** show the source and cleaned row counts and confirm
#    that they agree. Show the data type and missing-value count of every output
#    column. Explain any unexpected missing values.
# 2. **Three source checks:** choose three different records: an ordinary package,
#    a decimal package size, and a record with a missing or ambiguous size. If the
#    last category is absent, choose a packaging-modifier example instead.
#    Display the full raw `Product` and `Time` beside the relevant cleaned fields.
#    Write what the values should be by reading the source yourself, then compare
#    with your code's output. Identify the records so another person can find them.
# 3. **One independent calculation:** for a valid record, show the raw revenue,
#    units, and ounces. Calculate price per ounce yourself, using a calculator if
#    needed, and compare it with your computed column. Explain why dividing only
#    by ounces would give the wrong quantity.
# 4. **One limitation:** describe a real case your rules cannot confidently
#    resolve, or a boundary case you tested successfully. State how you handled
#    it and what additional information would resolve any uncertainty.
#
# The checks and explanations must be your own. A second AI response saying the
# code is correct is not independent verification.

# %% [markdown]
# ### Check records and output columns
#
# Show source and cleaned row counts, and the data type and missing-value count of each output column.
#
# **My approach or prediction:**
#
# *Replace this sentence with your own explanation before writing the code.*

# %%
# Your code here

# %% [markdown]
# ### Explain and check
#
# Do the row counts agree? Explain any unexpected missing values.
#
# **My response:**
#
# *Write your response here.*

# %% [markdown]
# ### Predict three source records
#
# Choose the three source records described above. Identify each record and read
# its raw description and time **before** comparing with the cleaned output.
#
# | Check | Record identifier / source index | What I expect from reading the source |
# | --- | --- | --- |
# | Ordinary package | *Fill in* | *Fill in* |
# | Decimal package size | *Fill in* | *Fill in* |
# | Missing/ambiguous size, or packaging modifier if absent | *Fill in* | *Fill in* |

# %% [markdown]
# ### Compare your three source records
#
# Display the full raw `Product` and `Time` beside the relevant cleaned fields for those records. Keep each source record matched to its own cleaned values.
#
# **My approach or prediction:**
#
# *Replace this sentence with your own explanation before writing the code.*

# %%
# Your code here

# %% [markdown]
# ### Explain and check
#
# Compare your predictions with the cleaned output. Explain discrepancies and any revisions to your rules.
#
# **My response:**
#
# *Write your response here.*

# %% [markdown]
# ### One independent calculation
#
# *Identify a valid record. Write its raw revenue, unit sales, and ounces. Show
# your own price-per-ounce calculation, using a calculator if needed. Explain
# why dividing revenue only by ounces would give the wrong quantity.*

# %% [markdown]
# ### Compare the calculated value
#
# Display the computed `Price Per Oz` for that same record and compare it with your independent calculation.
#
# **My approach or prediction:**
#
# *Replace this sentence with your own explanation before writing the code.*

# %%
# Your code here

# %% [markdown]
# ### One limitation or boundary case
#
# *Describe a real unresolved case or a boundary case you tested successfully. Explain how you handled it and what additional information would resolve any remaining uncertainty.*

# %% [markdown]
# ## Finish and submit
#
# Sort by `Week Ending` ascending, then `Dollar Sales` descending. Reset the index
# with `drop=True`. Display the first ten rows of the final table, using these
# ten columns:
#
# ```text
# Week Ending, Description, Dollar Sales, Unit Sales, Packaging,
# Product, Flavor, Product Code, Oz, Price Per Oz
# ```
#
# Save `sales` locally as `05-cleaned_sales.csv` without the DataFrame index.
# Restart the notebook kernel, run all cells in order, and save the notebook
# with its outputs visible.
#
# At the end, include a short assistance note: what you asked Codex, one useful
# hint or correction, and how you checked the resulting change. If you did not
# use Codex, say so. You do not need to submit a full chat transcript.
#
# Submit **one file**, `module05_ralphs.ipynb`, to the **Module 5 homework assignment
# on Gradescope**. It must include your code, outputs, source checks, explanations,
# and assistance note. The exported CSV is generated by the notebook and does not
# need a separate upload. Follow the posted course calendar for the deadline.

# %% [markdown]
# ### Prepare the final table
#
# Put the ten specified columns in the stated order. Sort by `Week Ending` ascending, then `Dollar Sales` descending; reset the index with `drop=True`. Display the first ten rows.
#
# **My approach or prediction:**
#
# *Replace this sentence with your own explanation before writing the code.*

# %%
# Your code here

# %% [markdown]
# ### Export your cleaned data
#
# Save `sales` locally as `05-cleaned_sales.csv` without the DataFrame index. This CSV does not need a separate Gradescope upload.
#
# **My approach or prediction:**
#
# *Replace this sentence with your own explanation before writing the code.*

# %%
# Your code here

# %% [markdown]
# ### Assistance note
#
# *Describe what you asked Codex, one useful hint or correction, and how you checked the change. If you did not use Codex, say so.*

# %% [markdown]
# ### Before uploading to Gradescope
#
# - [ ] All six sections are completed with my own code and explanations.
# - [ ] Source checks, an independent calculation, and a limitation are included.
# - [ ] The original data and `raw` remain unchanged; every source row is retained.
# - [ ] The final table has the required columns, ordering, and reset index.
# - [ ] My notebook generates `05-cleaned_sales.csv` locally.
# - [ ] I restarted the kernel, ran all cells in order, and saved visible outputs.
# - [ ] I replaced the response placeholders and included an assistance note.
# - [ ] I uploaded **`module05_ralphs.ipynb`** to the **Module 5 homework assignment on Gradescope**.
#
# Use the posted course calendar for the deadline. Do not push your submission to
# the shared course repository.
